# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

from ultralytics import YOLO

# %%
## Training Baseline model

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="data/data.yaml", 
    epochs=50,           
    imgsz=640,          
    batch=16,            
    device=0,            
    project="runs/detect",
    name="baseline"
)
# Out:
# Ultralytics 8.3.237  Python-3.11.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
model_2 = YOLO("yolov8s.pt")

# %%
model_2.train(
    data="data/data.yaml", 
    epochs=50,           
    imgsz=640,          
    batch=16,            
    device=0,            
    project="runs/detect",
    name="v8s"
)
# Out:
# Ultralytics 8.3.237  Python-3.11.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
model_3 = YOLO("yolov10n.pt")

# %%
model_3.train(
    data="data/data.yaml", 
    epochs=50,           
    imgsz=640,          
    batch=16,            
    device=0,            
    project="runs/detect",
    name="v10n"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.237  Python-3.11.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
model_4 = YOLO('yolov10s.pt')

# %%
model_4.train(
    data="data/data.yaml", 
    epochs=50,           
    imgsz=640,          
    batch=16,            
    device=0,            
    project="runs/detect",
    name="v10s"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.237  Python-3.11.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
